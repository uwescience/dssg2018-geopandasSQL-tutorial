# %% [markdown]
# # Introduction to Jupyter notebooks and Pandas

# %% [markdown]
# ## 1. Opening and Navigating the IPython Notebook
#
# We will start today with the interactive environment that we will be using in the tutorial: the [Jupyter Notebook](http://jupyter.org).
#
# We will walk through the following steps together:
#
# 1. (If you don't yet have anaconda) Download [miniconda](https://conda.io/miniconda.html) (be sure to get Version 3.6) and install it on your system (hopefully you have done this before coming to class)
#    ```
#    ```
#
# 2. Use the ``conda`` command-line tool to update your package listing and install the IPython notebook:
#
#    Update ``conda``'s listing of packages for your system:
#    ```
#    $ conda update conda
#    ```
#
#    Install IPython notebook and all its requirements
#    ```
#    $ conda install jupyter notebook
#    ```
#
# 4. Use git to clone our repo:
#
# ```
# git clone https://github.com/uwescience/dssg2018-geopandasSQL-tutorial
# ```
#
# 3. Navigate to the directory containing the tutorial material
#
#    ```
#    $ cd ~/dssg2018-geopandasSQL-tutorial/
#    ```
#
#    You should see a number of files in the directory, including these:
#
#    ```
#    $ ls
#    ...
#    0-Jupyter-notebooks.ipynb
#    1-intro-geopandas.ipynb
#    ...
#    ```
#
# 4. Type ``jupyter notebook`` in the terminal to start the notebook
#
#    ```
#    $ jupyter notebook
#    ```
#
#    If everything has worked correctly, it should automatically launch your default browser
#    ```
#    ```
#
# 5. Click on ``0-Jupyter-numpy.ipynb`` to open the notebook containing the content for this lecture.
#
# With that, you're set up to use the Jupyter notebook!

# %% [markdown]
# ## About Jupyter
#
# - Combines the features of an IPython terminal with a fancy web interface
# - Every notebook has one python instance running with it
# - Also supports markdown and html embedding
# - Easy to insert $\LaTeX$ formulas
# - Be ware of VIM-style keyboard shortcuts

# %% [markdown]
# ## Python refresher
# - Components with the same capabilities are of the same *type*.
#   - For example, the numbers 2 and 200 are both integers.
#   - This is called "duck typing" (if it looks like a duck, quacks like a duck...)
#
# - A type is defined recursively. Some examples.
#   - A list is a collection of objects that can be indexed by position.
#   - A list of integers contains an integer at each position.
#
# - A type has a set of supported operations. For example:
#   - Integers can be added
#   - Strings can be concatented
#   - A table can find the name of its columns
#
# - In python, members (components and operations) are indicated by a '.'
#   - If `a` is a list, the `a.append(1)` adds `1` to the list.

# %%
a = 1

# %%
# Python lists can store data of different types at the same time
a_list = [1, 'a', [1,2]]

# %%
# What if we forgot what functions a list has?
a_list.pop?

# %%
a_list.append(2)

# %%
1
# Out:
# 1

# %%
a_list
# Out:
# [1, 'a', [1, 2], 2]

# %%
1
# Out:
# 1

# %%
# What are the full set of functions available for our list
a_list.
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
# Count how many times the integer '1' occurs
a_list.count(1)

# %% [markdown]
# ## The IPython kernel/client model

# %%
# %connect_info
# Out:
# {
#   "shell_port": 57896,
#   "iopub_port": 57897,
#   "stdin_port": 57898,
#   "control_port": 57899,
#   "hb_port": 57900,
#   "ip": "127.0.0.1",
#   "key": "d35b7ce7-38529646d0d2edcc15288ed9",
#   "transport": "tcp",
#   "signature_scheme": "hmac-sha256",
#   "kernel_name": ""
# }
#
# Paste the above JSON into a file, and connect with:
#     $> jupyter <app> --existing <file>
# or, if you are local, you can connect with just:
#     $> jupyter <app> --existing kernel-71ec3129-90c4-4637-af36-85e0771b93d4.json
# or even just:
#     $> jupyter <app> --existing
# if this is the most recent Jupyter kernel you have started.

# %% [markdown]
# We can connect automatically a Qt Console to the currently running kernel with the %qtconsole magic, or by typing ipython console --existing <kernel-UUID> in any terminal:

# %%
# %qtconsole magic

# %% [markdown]
# ## Python's Data Science Ecosystem
#
# There are also many often-used third-party modules that are core tools for doing data science with Python.
# Some of the most important ones are:
#
# #### [``numpy``](http://numpy.org/): Numerical Python
#
# Numpy is short for "Numerical Python", and contains tools for efficient manipulation of arrays of data.
# If you have used other computational tools like IDL or MatLab, Numpy should feel very familiar.
#
# #### [``scipy``](http://scipy.org/): Scientific Python
#
# Scipy is short for "Scientific Python", and contains a wide range of functionality for accomplishing common scientific tasks, such as optimization/minimization, numerical integration, interpolation, and much more.
#
# #### [``pandas``](http://pandas.pydata.org/): Labeled Data Manipulation in Python
#
# Pandas is short for "Panel Data", and contains tools for doing more advanced manipulation of labeled data in Python, in particular with a columnar data structure called a *Data Frame*.
# If you've used the [R](http://rstats.org) statistical language , much of the functionality in Pandas should feel very familiar.
#
# #### [``matplotlib``](http://matplotlib.org): Visualization in Python
#
# Matplotlib started out as a Matlab plotting clone in Python, and has grown from there in the 15 years since its creation. It is the most popular data visualization tool currently in the Python data world (though other recent packages are starting to encroach on its monopoly).

# %%
import pandas as pd

# %%
pd.read_csv?

# %%
df = pd.read_csv('data/Places_Full.csv')

# %%
df
# Out:
#                                                    name  \
# 0                                          Trader Joe's
# 1                                      Hillcrest Market
# 2                                             Uwajimaya
# 3                                 Kress IGA Supermarket
# 4                                         Double Dorjee
# 5                                    Whole Foods Market
# 6                         Grocery Outlet Bargain Market
# 7                            Metropolitan Market Uptown
# 8                                          Trader Joe's
# 9                                         Foulee Market
# 10                                   Whole Foods Market
# 11                                 Seattle Super Market
# 12                                  Metropolitan Market
# 13                                         Trader Joe's
# 14                                         Trader Joe's
# 15                       Metropolitan Market Sand Point
# 16               Seattle Public Library-Central Library
# 17    Douglass-Truth Branch - The Seattle Public Lib...
# 18    International District/Chinatown Branch - The ...
# 19     Capitol Hill Branch - The Seattle Public Library
# 20    Madrona-Sally Goldmark Branch - The Seattle Pu...
# 21      Beacon Hill Branch - The Seattle Public Library
# 22         Montlake Branch - The Seattle Public Library
# 23       Queen Anne Branch - The Seattle Public Library
# 24          Fremont Branch - The Seattle Public Library
# 25                   Swedish Pain Services - First Hill
# 26    Swedish / First Hill Lytle Center for Pregnanc...
# 27    Swedish Medical Center First Hill 2nd Floor En...
# 28               Swedish Orthopedic Institute - Seattle
# 29                                              Swedish
# ...                                                 ...
# 1586                                       Madison Park
# 1587                                      Gasworks Park
# 1588                                        Seward Park
# 1589                                       Lincoln Park
# 1590                                     Volunteer Park
# 1591                                    Lake Union Park
# 1592                                     Jefferson Park
# 1593                                      Magnusan Park
# 1594                                  Cal Anderson Park
# 1595                                     Greenlake Park
# 1596                             Olympic Sculpture Park
# 1597                                       Madrona Park
# 1598                                      Kubota Garden
# 1599                                       Carkeek Park
# 1600                                Myrtle Edwards Park
# 1601                            Seattle Central College
# 1602                              North Seattle College
# 1603                              South Seattle College
# 1604                                King Street Station
# 1605                                    Westlake Center
# 1606                           Northgate Transit Center
# 1607                                  Downtown Bellevue
# 1608                                            Tukwila
# 1609                                               SODO
# 1610                                   Overlake-Redmond
# 1611                            Downtown Pioneer Square
# 1612                           Downtown Commercial Core
# 1613                           University of Washington
# 1614                                         First Hill
# 1615                                   South Lake Union
#
#                             address     city        lat         lng  \
# 0          1700 East Madison Street  Seattle  47.615866 -122.309913
# 1            110 Summit Avenue East  Seattle  47.618850 -122.325005
# 2              600 5th Avenue South  Seattle  47.596843 -122.326929
# 3                   1427 3rd Avenue  Seattle  47.609396 -122.337822
# 4            1501 Pike Street # 511  Seattle  47.608822 -122.339570
# 5              2210 Westlake Avenue  Seattle  47.618344 -122.338097
# 6             1702 4th Avenue South  Seattle  47.587870 -122.328625
# 7                 100 Mercer Street  Seattle  47.624805 -122.354842
# 8      1916 Queen Anne Avenue North  Seattle  47.636582 -122.356759
# 9          2050 South Columbian Way  Seattle  47.559965 -122.305132
# 10            2001 15th Avenue West  Seattle  47.637222 -122.376892
# 11         4801 Beacon Avenue South  Seattle  47.559427 -122.304890
# 12       2320 42nd Avenue Southwest  Seattle  47.581632 -122.384629
# 13     4555 Roosevelt Way Northeast  Seattle  47.662670 -122.317620
# 14    4545 Fauntleroy Way Southwest  Seattle  47.561965 -122.381010
# 15       5250 40th Avenue Northeast  Seattle  47.668187 -122.283622
# 16                     1000 4th Ave  Seattle  47.606701 -122.332501
# 17             2300 East Yesler Way  Seattle  47.601918 -122.301650
# 18             713 8th Avenue South  Seattle  47.596233 -122.322784
# 19          425 Harvard Avenue East  Seattle  47.622929 -122.322319
# 20                 1134 33rd Avenue  Seattle  47.612675 -122.290020
# 21         2821 Beacon Avenue South  Seattle  47.577991 -122.311403
# 22            2401 24th Avenue East  Seattle  47.640520 -122.302401
# 23         400 West Garfield Street  Seattle  47.633814 -122.362665
# 24            731 North 35th Street  Seattle  47.650062 -122.348423
# 25                600 Broadway #530  Seattle  47.607753 -122.320077
# 26               1296 Cherry Street  Seattle  47.608130 -122.321543
# 27                     747 Broadway  Seattle  47.608691 -122.321520
# 28                     601 Broadway  Seattle  47.607473 -122.321381
# 29                     747 Broadway  Seattle  47.608866 -122.321908
# ...                             ...      ...        ...         ...
# 1586                            NaN      NaN  47.635897 -122.276901
# 1587                            NaN      NaN  47.646570 -122.335308
# 1588                            NaN      NaN  47.550034 -122.257778
# 1589                            NaN      NaN  47.530419 -122.393117
# 1590                            NaN      NaN  47.631061 -122.315451
# 1591                            NaN      NaN  47.626200 -122.337323
# 1592                            NaN      NaN  47.568994 -122.308655
# 1593                            NaN      NaN  47.680326 -122.253198
# 1594                            NaN      NaN  47.617320 -122.319570
# 1595                            NaN      NaN  47.680250 -122.328499
# 1596                            NaN      NaN  47.616675 -122.355396
# 1597                            NaN      NaN  47.610256 -122.283617
# 1598                            NaN      NaN  47.513127 -122.266398
# 1599                            NaN      NaN  47.711609 -122.372217
# 1600                            NaN      NaN  47.619871 -122.361605
# 1601                            NaN      NaN  47.616587 -122.321611
# 1602                            NaN      NaN  47.699252 -122.333520
# 1603                            NaN      NaN  47.548410 -122.352194
# 1604                            NaN      NaN  47.598939 -122.329158
# 1605                            NaN      NaN  47.611603 -122.336910
# 1606                            NaN      NaN  47.702358 -122.327210
# 1607                            NaN      NaN  47.615523 -122.199049
# 1608                            NaN      NaN  47.455556 -122.254492
# 1609                            NaN      NaN  47.583574 -122.333555
# 1610                            NaN      NaN  47.641193 -122.128259
# 1611                            NaN      NaN  47.601651 -122.334226
# 1612                            NaN      NaN  47.608001 -122.334658
# 1613                            NaN      NaN  47.655614 -122.305211
# 1614                            NaN      NaN  47.609422 -122.325120
# 1615                            NaN      NaN  47.622933 -122.337105
#
#                          place_id  rating             class  \
# 0     ChIJx0M1ztNqkFQRtgspEllQxk8     4.5       supermarket
# 1     ChIJt5emCTMVkFQR-BCgFDTvu9o     3.5       supermarket
# 2     ChIJq9nX27xqkFQRu05rxkrN7f4     4.5       supermarket
# 3     ChIJbdIhoLNqkFQRMTiHCN6W4nU     3.9       supermarket
# 4     ChIJkX3s-LJqkFQRQRexqCN0jQY     5.0       supermarket
# 5     ChIJyz9g9EkVkFQRutvXu56_BLk     4.3       supermarket
# 6     ChIJIWM_pp5qkFQRsh-E4oUVcIM     4.3       supermarket
# 7     ChIJsY2q3UMVkFQRBAbqlwfTqdE     4.5       supermarket
# 8     ChIJn-z5HhMVkFQR0APZKI1twvM     4.6       supermarket
# 9     ChIJmbwZA99BkFQRIACApE5YiTQ     4.2       supermarket
# 10    ChIJOTwRwHAVkFQRYGVIWtpc7YQ     4.2       supermarket
# 11    ChIJjwx9VN5BkFQRWRSE9mEfmo0     3.9       supermarket
# 12    ChIJCS8FRG9AkFQRay47maLdNsc     4.6       supermarket
# 13    ChIJq6Rq_l8UkFQRyDDI__HHS40     4.5       supermarket
# 14    ChIJp_YVBUNAkFQRe9kml96hW9g     4.5       supermarket
# 15    ChIJ5W3fE34TkFQRNkqlEtO1Z48     4.4       supermarket
# 16    ChIJ55fLWVtBkFQR0v31eadEoLM     4.7           library
# 17    ChIJz7j3fcJqkFQR4IjrnHLzv74     4.5           library
# 18    ChIJn-krn71qkFQR54uojagWKD8     4.4           library
# 19    ChIJ1Y9IDC4VkFQRteLhIs-Bf4I     4.5           library
# 20    ChIJ3XHObSdrkFQR1ZG6wstVcZ8     4.9           library
# 21    ChIJQ2xGQIdqkFQRDAwVMNgC7gI     4.5           library
# 22    ChIJU2vyhcMUkFQRG9TOL-sJups     4.4           library
# 23    ChIJEw6qRGwVkFQRNJYY6wj_LXY     4.4           library
# 24    ChIJoz291gAVkFQR5-kw3WppwvU     4.6           library
# 25    ChIJ-0tZb8hqkFQR34w031as_LE     4.0          hospital
# 26    ChIJK58VR8hqkFQRkI26eknR7F0     5.0          hospital
# 27    ChIJWy99TshqkFQR7EMvj1bczcM     4.2          hospital
# 28    ChIJ2UdDFMhqkFQRE9lczfbh4OI     4.3          hospital
# 29    ChIJIaimVchqkFQROvSZca1wkjo     3.7          hospital
# ...                           ...     ...               ...
# 1586                 Madison-Park     NaN  destination park
# 1587                Gasworks-Park     NaN  destination park
# 1588                  Seward-Park     NaN  destination park
# 1589                 Lincoln-Park     NaN  destination park
# 1590               Volunteer-Park     NaN  destination park
# 1591              Lake-Union-Park     NaN  destination park
# 1592               Jefferson-Park     NaN  destination park
# 1593                Magnusan-Park     NaN  destination park
# 1594            Cal-Anderson-Park     NaN  destination park
# 1595               Greenlake-Park     NaN  destination park
# 1596       Olympic-Sculpture-Park     NaN  destination park
# 1597                 Madrona-Park     NaN  destination park
# 1598                Kubota-Garden     NaN  destination park
# 1599                 Carkeek-Park     NaN  destination park
# 1600          Myrtle-Edwards-Park     NaN  destination park
# 1601      Seattle-Central-College     NaN          citywide
# 1602        North-Seattle-College     NaN          citywide
# 1603        South-Seattle-College     NaN          citywide
# 1604          King-Street-Station     NaN          citywide
# 1605              Westlake-Center     NaN          citywide
# 1606     Northgate-Transit-Center     NaN          citywide
# 1607              Bellevue-Square     NaN          citywide
# 1608                      Tukwila     NaN          citywide
# 1609                         SODO     NaN          citywide
# 1610             Overlake-Redmond     NaN          citywide
# 1611      Downtown-Pioneer-Square     NaN          citywide
# 1612     Downtown-Commercial-Core     NaN          citywide
# 1613     University-of-Washington     NaN          citywide
# 1614                   First-Hill     NaN          citywide
# 1615             South-Lake-Union     NaN          citywide
#
#                        type
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21                      NaN
# 22                      NaN
# 23                      NaN
# 24                      NaN
# 25                      NaN
# 26                      NaN
# 27                      NaN
# 28                      NaN
# 29                      NaN
# ...                     ...
# 1586                    NaN
# 1587                    NaN
# 1588                    NaN
# 1589                    NaN
# 1590                    NaN
# 1591                    NaN
# 1592                    NaN
# 1593                    NaN
# 1594                    NaN
# 1595                    NaN
# 1596                    NaN
# 1597                    NaN
# 1598                    NaN
# 1599                    NaN
# 1600                    NaN
# 1601                College
# 1602                College
# 1603                College
# 1604            Transit Hub
# 1605            Transit Hub
# 1606            Transit Hub
# 1607  Major Employment Area
# 1608  Major Employment Area
# 1609  Major Employment Area
# 1610  Major Employment Area
# 1611  Major Employment Area
# 1612  Major Employment Area
# 1613  Major Employment Area
# 1614  Major Employment Area
# 1615  Major Employment Area
#
# [1616 rows x 9 columns]

# %% [markdown]
# ### What to do next?
#
# Now that we've loaded our .csv file into a pandas data frame, we have some powerful tools available to us. In the next segment we'll see a sample of operations we can do with pandas and geopandas.
